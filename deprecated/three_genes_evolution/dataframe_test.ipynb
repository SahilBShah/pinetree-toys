# %%
import pandas as pd

# %%
genome_tracker = pd.read_csv("gene_tracker.tsv", header=0, sep='\t')
f_old = 1.0

# %%
genome_tracker['value'].values[12] = f_old

# %%
genome_tracker['value'].values[12]
# Out:
# 1.0

# %%
genome_tracker
# Out:
#         species  start   stop  new_strength  previous_strength  value
# 0         geneX   26.0  121.0           NaN                NaN    NaN
# 1         geneY  159.0  280.0           NaN                NaN    NaN
# 2         geneZ  319.0  449.0           NaN                NaN    NaN
# 3     promoter1    1.0   10.0           0.0                0.0    NaN
# 4     promoter2    0.0    0.0           0.0                0.0    NaN
# 5     promoter3    0.0    0.0           0.0                0.0    NaN
# 6        rnase1    0.0    0.0           NaN                NaN    NaN
# 7        rnase2    0.0    0.0           NaN                NaN    NaN
# 8        rnase3    0.0    0.0           NaN                NaN    NaN
# 9   terminator1    0.0    0.0           0.0                0.0    NaN
# 10  terminator2    0.0    0.0           0.0                0.0    NaN
# 11  terminator3    0.0    0.0           0.0                0.0    NaN
# ...
